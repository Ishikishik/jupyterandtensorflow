# %%
#ライブラリ読み込み
from PIL import Image
import numpy as np #numpyをこの先npという
import matplotlib.pyplot as plt

# %%
#画像を行列として表示する

# NumPyの行列表示制限を解除
#np.set_printoptions(threshold=np.inf)

# 画像のパスを指定
image_path = "/home/jovyan/work/test.JPG"

# 画像を開く
image = Image.open(image_path)

# 画像をNumPyの行列に変換
image_array = np.array(image)

# 画像を表示
plt.imshow(image)
plt.axis('off')  # 軸を非表示
plt.show()

# ピクセル行列を表示
print(image_array)
# Out:
# [[[226 233 241]
#   [227 234 242]
#   [228 235 243]
#   ...
#   [175 170 164]
#   [181 176 170]
#   [187 182 176]]
#
#  [[227 234 242]
#   [227 234 242]
#   [227 234 242]
#   ...
#   [177 172 166]
#   [183 178 172]
#   [188 183 177]]
#
#  [[228 235 243]
#   [227 234 242]
#   [226 233 241]
#   ...
#   [180 175 169]
#   [185 180 174]
#   [187 182 176]]
#
#  ...
#
#  [[243 251 254]
#   [243 251 254]
#   [243 251 254]
#   ...
#   [127 117 105]
#   [123 113 101]
#   [123 113 101]]
#
#  [[243 251 254]
#   [243 251 254]
#   [243 251 254]
#   ...
#   [128 118 106]
#   [125 115 103]
#   [127 117 105]]
#
#  [[243 251 254]
#   [243 251 254]
#   [243 251 254]
#   ...
#   [129 119 107]
#   [128 118 106]
#   [130 120 108]]]

# %%
#行列を画像にする

# サンプルの行列 (RGB画像の例、3x3ピクセル)
image_array = np.array([
    [[255, 0, 0], [0, 255, 0], [0, 0, 255]],    # 3ピクセル（赤, 緑, 青）
    [[255, 255, 0], [0, 255, 255], [255, 0, 255]],  # 黄色, シアン, マゼンタ
    [[0, 0, 0], [128, 128, 128], [255, 255, 255]]  # 黒, グレー, 白
], dtype=np.uint8)

# 行列を画像に変換
image = Image.fromarray(image_array)

# 画像を表示
image.show()

# 画像を保存
image.save("output_image.png")
# Out:
# xdg-mime: mimetype argument missing
# Try 'xdg-mime --help' for more information.
